# %% [markdown]
# # Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
# Set path

path = r"C:\Users\marce\Documents\Instacart Basket Analysis"

# %%
# Import ords_prods_merged_02.pkl

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
# Drop columns '_merge' and 'exists'

ords_prods_merge= ords_prods_merge.drop(columns = ['_merge', 'exists'])

# %%
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   orders_day_of_week      int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float16
#  6   product_id              float16
#  7   add_to_cart_order       float16
#  8   reordered               float16
#  9   product_name            object
#  10  aisle_id                int8
#  11  department_id           int8
#  12  prices                  float16
#  13  price_range_loc         object
#  14  busiest_day             object
#  15  busiest_days            object
#  16  busiest_period_of_day   object
# dtypes: float16(5), int32(2), int8(5), object(5)
# memory usage: 2.1+ GB

# %% [markdown]
# # 2. Find the aggregated mean of the “order_number” column grouped by “department_id”

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset?
# For the entire dataframe we have all department_ids and the mean of the 'order_number' it has changed, decreasing for all departments, with the exception of department_id 17, which increased.

# %% [markdown]
# # 4. Create a loyalty flag for existing customers using the transform() and loc() functions

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'order_number' column to generate the max orders for each user.

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ### Create a flag that assigns a 'loyalty' label to a user ID based on its corresponding max order value

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']<=40) & (ords_prods_merge['max_order']> 10), 'loyalty_flag']= 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10, 'loyalty_flag']='New customer'

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
# ...

# %%
#Checking the count of 'loyalty_flag' values

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
#  # 5. Check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer)

# %%
# Produce multiple statistic (mean, min, max, sum) using agg() 

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']}, skipna=False)
# Out:
#                  prices
#                    mean  min  max sum
# loyalty_flag
# Loyal customer      NaN  1.0  inf NaN
# New customer        NaN  1.0  inf NaN
# Regular customer    NaN  1.0  inf NaN

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean              NaN
# std               NaN
# min      1.000000e+00
# 25%      4.199219e+00
# 50%      7.398438e+00
# 75%      1.129688e+01
# max               inf
# Name: prices, dtype: float64

# %%
ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 1                         7                    15.0       196.0
# ...

# %%
ords_prods_merge['prices'].isna().any()
# Out:
# False

# %%
# Replace "Inf" values with NaN
ords_prods_merge.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Drop rows with "NaN" values
ords_prods_merge.dropna(subset=['prices'], inplace=True)

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']}, skipna=False)
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer     9.578717  1.0  14896.0   98507624.0
# New customer      10.059199  1.0  14896.0   62807508.0
# Regular customer   9.894030  1.0  14896.0  157081200.0

# %%
ords_prods_merge.tail(15)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404844   1928449   202557             4                   4
# 32404845   2222639   202557             6                   5
# 32404846    339942   202557             8                   4
# 32404847   2798193   202557             9                   4
# 32404848   2391791   202557            11                   6
# 32404849    576295   202557            12                   3
# 32404850    960088   202557            13                   4
# 32404851    343962   202557            14                   0
# 32404852   2329472   202557            15                   6
# 32404853    694731   202557            16                   1
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# ...

# %%
# Export ords_prods_merge in csv format

ords_prods_merge.to_csv(r'C:\Users\marce\Documents\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merge_3a.csv')
